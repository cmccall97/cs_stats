# %%
from demoparser2 import DemoParser
import pandas as pd
from nade_efficacy_pipeline import process_multiple_demos

# %%
demo_list = [
    'g2-vs-faze-m2-inferno-p1.dem',
    'g2-vs-faze-m2-inferno-p2.dem',
    'g2-vs-faze-m3-nuke.dem'
]

result = process_multiple_demos(demo_list)
# Out:
# {'g2-vs-faze-m2-inferno-p1.dem': Empty DataFrame
#  Columns: [count, user_name, dmg_health, avg_dmg_per_HE]
#  Index: [],
#  'g2-vs-faze-m2-inferno-p2.dem':   user_name  count  dmg_health  avg_dmg_per_HE
#  0     EliGE      5       139.0            27.8
#  1    frozen      6        73.0            12.2
#  2    m0NESY      9       171.0            19.0
#  3     broky      1         0.0             0.0
#  4      rain      0         0.0             NaN
#  5  HeavyGoD      4       154.0            38.5
#  6   malbsMd      9        84.0             9.3
#  7   huNter-      9       170.0            18.9
#  8      Snax      8        39.0             4.9
#  9  karrigan      5        20.0             4.0,
#  'g2-vs-faze-m3-nuke.dem':   user_name  count  dmg_health  avg_dmg_per_HE
#  0  karrigan      9         6.0             0.7
#  1     broky      7        66.0             9.4
#  2    frozen     15       185.0            12.3
#  3    m0NESY      7        53.0             7.6
# ...

# %%
demo1 = result['g2-vs-faze-m3-nuke.dem']
demo1
# Out:
#   user_name  count  dmg_health  avg_dmg_per_HE
# 0  karrigan      9         6.0             0.7
# 1     broky      7        66.0             9.4
# 2    frozen     15       185.0            12.3
# 3    m0NESY      7        53.0             7.6
# 4  HeavyGoD     12         0.0             0.0
# 5   malbsMd      8       129.0            16.1
# 6   huNter-     10       107.0            10.7
# 7      Snax      5         0.0             0.0
# 8      rain      9        15.0             1.7
# 9     EliGE      7        36.0             5.1

# %%
demo2 = result['g2-vs-faze-m2-inferno-p2.dem']
demo2
# Out:
#   user_name  count  dmg_health  avg_dmg_per_HE
# 0     EliGE      5       139.0            27.8
# 1    frozen      6        73.0            12.2
# 2    m0NESY      9       171.0            19.0
# 3     broky      1         0.0             0.0
# 4      rain      0         0.0             NaN
# 5  HeavyGoD      4       154.0            38.5
# 6   malbsMd      9        84.0             9.3
# 7   huNter-      9       170.0            18.9
# 8      Snax      8        39.0             4.9
# 9  karrigan      5        20.0             4.0
